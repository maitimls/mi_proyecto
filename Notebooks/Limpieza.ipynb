# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
df_cafe_dirty = pd.read_csv("/Users/maitanelopezsanchez/mi_proyecto-1/Datasets/dirty_cafe_sales.csv")

# %%
df_cafe_dirty
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Comenzando la limpieza

# %%
#Transformar los tipos de datos a int y str.
df_cafe_dirty['Quantity'] = pd.to_numeric(df_cafe_dirty['Quantity'], errors='coerce')
df_cafe_dirty['Quantity'] = df_cafe_dirty['Quantity'].astype('Int64')

# %%
df_cafe_dirty['Price Per Unit'] = pd.to_numeric(df_cafe_dirty['Price Per Unit'], errors='coerce')

# %%
df_cafe_dirty['Transaction Date'] = pd.to_datetime(df_cafe_dirty['Transaction Date'], errors='coerce')

# %%
df_cafe_dirty['Total Spent'] = df_cafe_dirty['Total Spent'].astype(str)

df_cafe_dirty['Total Spent'] = df_cafe_dirty['Total Spent'].str.replace(r'[^0-9.]', '', regex=True)

df_cafe_dirty['Total Spent'] = pd.to_numeric(df_cafe_dirty['Total Spent'], errors='coerce')

# %%
cols = ['Transaction ID', 'Item', 'Payment Method', 'Location']
df_cafe_dirty[cols] = df_cafe_dirty[cols].astype('string')

# %%
df_cafe_dirty.dtypes
# Out:
# Transaction ID      string[python]
# Item                string[python]
# Quantity                     Int64
# Price Per Unit             float64
# Total Spent                float64
# Payment Method      string[python]
# Location            string[python]
# Transaction Date    datetime64[ns]
# dtype: object

# %%
df_cafe_dirty.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373    Coffee         2             2.0          4.0
# 1    TXN_4977031      Cake         4             3.0         12.0
# 2    TXN_4271903    Cookie         4             1.0          NaN
# 3    TXN_7034554     Salad         2             5.0         10.0
# 4    TXN_3160411    Coffee         2             2.0          4.0
# 5    TXN_2602893  Smoothie         5             4.0         20.0
# 6    TXN_4433211   UNKNOWN         3             3.0          9.0
# 7    TXN_6699534  Sandwich         4             4.0         16.0
# 8    TXN_4717867      <NA>         5             3.0         15.0
# 9    TXN_2064365  Sandwich         5             4.0         20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11
# 5     Credit Card      <NA>       2023-03-31
# 6           ERROR  Takeaway       2023-10-06
# 7            Cash   UNKNOWN       2023-10-28
# 8            <NA>  Takeaway       2023-07-28
# 9            <NA>  In-store       2023-12-31

# %%
df_cafe_dirty.groupby("Item")["Price Per Unit"].first()
# Out:
# Item
# Cake        3.0
# Coffee      2.0
# Cookie      1.0
# ERROR       1.5
# Juice       3.0
# Salad       5.0
# Sandwich    4.0
# Smoothie    4.0
# Tea         1.5
# UNKNOWN     3.0
# Name: Price Per Unit, dtype: float64

# %% [markdown]
# Tras observar el valor de cada Item, podemos ver como hay una coincidencia con el Price Per Unit del Item "ERROR"

# %%
df_cafe_dirty["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0    2429
# 4.0    2331
# 2.0    1227
# 5.0    1204
# 1.0    1143
# 1.5    1133
# Name: count, dtype: int64

# %%
df_cafe_dirty[df_cafe_dirty["Price Per Unit"].isin(["Unknown", "ERROR"])]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df_cafe_dirty[df_cafe_dirty["Price Per Unit"].astype(str).str.contains("[A-Za-z]", regex=True)]
#De esta forma podemos ver si alguno de los valores del Price Per Unit tenía algún valor como "$" u otros.
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 56      TXN_3578141      Cake         5             NaN         15.0
# 65      TXN_4987129  Sandwich         3             NaN          NaN
# 68      TXN_8427104     Salad         2             NaN         10.0
# 85      TXN_8035512       Tea         3             NaN          4.5
# 104     TXN_7447872     Juice         2             NaN          6.0
# ...             ...       ...       ...             ...          ...
# 9924    TXN_5981429     Juice         2             NaN          6.0
# 9926    TXN_2464706      Cake         4             NaN         12.0
# 9961    TXN_2153100       Tea         2             NaN          3.0
# 9996    TXN_9659401      <NA>         3             NaN          3.0
# 9998    TXN_7695629    Cookie         3             NaN          3.0
#
#       Payment Method  Location Transaction Date
# 56              <NA>  Takeaway       2023-06-27
# 65              <NA>  In-store       2023-10-20
# 68              <NA>  In-store       2023-10-27
# 85              Cash   UNKNOWN       2023-10-29
# 104             <NA>      <NA>              NaT
# ...              ...       ...              ...
# 9924  Digital Wallet      <NA>       2023-12-24
# 9926  Digital Wallet  Takeaway       2023-11-09
# 9961            Cash      <NA>       2023-12-29
# 9996  Digital Wallet      <NA>       2023-06-02
# 9998  Digital Wallet      <NA>       2023-12-02
#
# [533 rows x 8 columns]

# %%
#A continuación, vamos a eliminar las filas que contengan valores nulos como son "NaN", "ERROR" o "UNKNOWN"
# tanto en la la columna Item como en la columna Price Per Unit, ya que, no nos aportan ninguna información.

# %%
invalid_values = ["ERROR", "UNKNOWN"]

# %%
#Función que elimine las filas donde AMBOS valores son invalid_values
mask_invalid_both = (
    (df_cafe_dirty["Item"].isin(invalid_values) | df_cafe_dirty["Item"].isna()) &
    (df_cafe_dirty["Price Per Unit"].isin(invalid_values) | df_cafe_dirty["Price Per Unit"].isna())
)

# %%
df_cafe_dirty = df_cafe_dirty[~mask_invalid_both]

# %%
df_cafe_dirty[
    (df_cafe_dirty["Item"].isin(invalid_values) | df_cafe_dirty["Item"].isna()) &
    (df_cafe_dirty["Price Per Unit"].isin(invalid_values) | df_cafe_dirty["Price Per Unit"].isna())
]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
df_cafe_dirty.shape
# Out:
# (9946, 8)

# %% [markdown]
# Hemos eliminado y guardado la primera fase de la limpieza, podemos ver que el tamaño de la tabla de ha reducido de 10.000 filas a 9.946.

# %% [markdown]
# El siguiente paso que quiero dar es transormar en valores tangibles aquellos invalid_values donde sabemos el precio por unidad y no el Item o a la inversa. Por ejemplo, sabemos que un Coffee vale 2.0 y la Cookie 1.0. Y al revés, donde el precio sea 1.0 y el Item un invalid_value poder decir que es una Cookie.
#     Nota: En algunos casos se complica ya que el precio de la Cake y del Juice es el mismo.

# %%
df_cafe_dirty.groupby("Item")["Price Per Unit"].first()
# Out:
# Item
# Cake        3.0
# Coffee      2.0
# Cookie      1.0
# ERROR       1.5
# Juice       3.0
# Salad       5.0
# Sandwich    4.0
# Smoothie    4.0
# Tea         1.5
# UNKNOWN     3.0
# Name: Price Per Unit, dtype: float64

# %% [markdown]
# Como podemos observar, los Item: "ERROR" tienen un Price Per Unit de 1.5. El único Item que tiene ese Precio es el Té, por ello podemos transformar los Item que sean ERROR a Té.

# %%
df_cafe_dirty.loc[
    (df_cafe_dirty["Item"] == "ERROR") & (df_cafe_dirty["Price Per Unit"] == 1.5),
    "Item"
] = "Tea"

# %%
df_cafe_dirty_tea = df_cafe_dirty[df_cafe_dirty["Price Per Unit"] == 1.5]

# %% [markdown]
# ### Segundo paso, transformar aquellos Item con invalid_values en un valor cuando se cumpla lo siguiente:
# Coffee → 2.0
# Cookie → 1.0
# Salad → 5.0
# Tea → 1.5
# En el caso de Items con Price Per Unit iguales no se podrá realizar este cambio.

# %%
mapping = {
    2.0: "Coffee",
    1.0: "Cookie",
    5.0: "Salad",
    1.5: "Tea"
}

# %%
for price_, item_name in mapping.items():
    df_cafe_dirty.loc[
        (df_cafe_dirty["Item"].isin(invalid_values)) &
        (df_cafe_dirty["Price Per Unit"] == price_),
        "Item"
    ] = item_name

# %%
#Verificación
df_cafe_dirty[df_cafe_dirty["Item"].isin(mapping.values())]
# Out:
#      Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373  Coffee         2             2.0          4.0
# 2       TXN_4271903  Cookie         4             1.0          NaN
# 3       TXN_7034554   Salad         2             5.0         10.0
# 4       TXN_3160411  Coffee         2             2.0          4.0
# 10      TXN_2548360   Salad         5             5.0         25.0
# ...             ...     ...       ...             ...          ...
# 9982    TXN_8567525  Cookie         2             1.0          2.0
# 9990    TXN_1538510  Coffee         5             2.0         10.0
# 9995    TXN_7672686  Coffee         2             2.0          4.0
# 9997    TXN_5255387  Coffee         4             2.0          8.0
# 9998    TXN_7695629  Cookie         3             NaN          3.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# 10              Cash  Takeaway       2023-11-07
# ...              ...       ...              ...
# 9982            <NA>  Takeaway       2023-12-30
# 9990  Digital Wallet      <NA>       2023-05-22
# 9995            <NA>   UNKNOWN       2023-08-30
# 9997  Digital Wallet      <NA>       2023-03-02
# 9998  Digital Wallet      <NA>       2023-12-02
#
# [4814 rows x 8 columns]

# %% [markdown]
# ### Tercer paso: Transformar los Price Per Unit que contengan invalid_values.

# %%
#Generamos un mapping con los precios de cada Item. Cake - 3.0, etc.
price_mapping = {
    "Cake": 3.0,
    "Coffee": 2.0,
    "Cookie": 1.0,
    "Juice": 3.0,
    "Salad": 5.0,
    "Sandwich": 4.0,
    "Smoothie": 4.0,
    "Tea": 1.5
}

# %%
for item_name, price_ in price_mapping.items():
    df_cafe_dirty.loc[
        (df_cafe_dirty["Price Per Unit"].isin(invalid_values) | df_cafe_dirty["Price Per Unit"].isna()) &
        (df_cafe_dirty["Item"] == item_name),
        "Price Per Unit"
    ] = price_

# %%
df_cafe_dirty[df_cafe_dirty["Price Per Unit"].isin(invalid_values)]
#Devuelve una tabla vacía por lo que ya no hay valores nulos en la columna Price Per Unit.
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %% [markdown]
# Debido a que los UNKNOWN que quedan tienen precio de 3.0 y de 4.0 y ese precio puede ser de 2 Items diferentes, considero que la mejor opción es eliminarlas ya que solo son 147 de 10.000 filas.

# %%
df_cafe_dirty[df_cafe_dirty["Item"] != "UNKNOWN"]
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee        2             2.0          4.0
# 1       TXN_4977031      Cake        4             3.0         12.0
# 2       TXN_4271903    Cookie        4             1.0          4.0
# 3       TXN_7034554     Salad        2             5.0         10.0
# 4       TXN_3160411    Coffee        2             2.0          4.0
# ...             ...       ...      ...             ...          ...
# 9993    TXN_4766549  Smoothie        2             4.0          8.0
# 9995    TXN_7672686    Coffee        2             2.0          4.0
# 9997    TXN_5255387    Coffee        4             2.0          8.0
# 9998    TXN_7695629    Cookie        3             1.0          3.0
# 9999    TXN_6170729  Sandwich        3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9993            Cash      <NA>       2023-10-20
# 9995            <NA>   UNKNOWN       2023-08-30
# 9997  Digital Wallet      <NA>       2023-03-02
# 9998  Digital Wallet      <NA>       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [9799 rows x 8 columns]

# %%
df_cafe_dirty_unknown = df_cafe_dirty[df_cafe_dirty["Item"] == "UNKNOWN"]
#Ver el tamaño de filas de Unkonws.
df_cafe_dirty_unknown
# Out:
#      Transaction ID     Item Quantity  Price Per Unit  Total Spent  \
# 6       TXN_4433211  UNKNOWN        3             3.0          9.0
# 36      TXN_6855453  UNKNOWN        4             3.0         12.0
# 91      TXN_5455936  UNKNOWN        5             3.0         15.0
# 153     TXN_6541415  UNKNOWN      4.0             3.0         12.0
# 165     TXN_3226832  UNKNOWN        5             4.0         20.0
# ...             ...      ...      ...             ...          ...
# 9727    TXN_3562418  UNKNOWN        2             4.0          8.0
# 9763    TXN_7652830  UNKNOWN        2             3.0          6.0
# 9836    TXN_9162296  UNKNOWN        3             4.0         12.0
# 9946    TXN_8807600  UNKNOWN        1             4.0          4.0
# 9994    TXN_7851634  UNKNOWN        4             4.0         16.0
#
#       Payment Method  Location Transaction Date
# 6              ERROR  Takeaway       2023-10-06
# 36              <NA>  In-store       2023-07-17
# 91              <NA>  In-store       2023-10-28
# 153             Cash  In-store       2023-11-25
# 165             Cash   UNKNOWN       2023-09-04
# ...              ...       ...              ...
# 9727  Digital Wallet   UNKNOWN       2023-08-13
# 9763            <NA>      <NA>       2023-08-15
# 9836            Cash  In-store       2023-05-10
# 9946            Cash  Takeaway       2023-09-24
# 9994            <NA>      <NA>       2023-01-08
#
# [147 rows x 8 columns]

# %%
df_cafe_dirty['Quantity'].isna().sum()
# Out:
# np.int64(35)

# %%
df_cafe_dirty_quantity_nan = df_cafe_dirty[df_cafe_dirty["Quantity"].isna()]
df_cafe_dirty_quantity_nan
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad     <NA>             5.0          NaN
# 278     TXN_3229409     Juice     <NA>             3.0          NaN
# 629     TXN_9289174      Cake     <NA>             3.0         12.0
# 641     TXN_2962976     Juice     <NA>             3.0          NaN
# 738     TXN_8696094  Sandwich     <NA>             4.0          NaN
# 912     TXN_1575608  Sandwich     <NA>             4.0         20.0
# 1008    TXN_7225428       Tea     <NA>             1.5          3.0
# 1436    TXN_7590801       Tea     <NA>             1.5          6.0
# 1482    TXN_3593060  Smoothie     <NA>             4.0         16.0
# 2330    TXN_3849488     Salad     <NA>             5.0          5.0
# 2796    TXN_9188692      Cake     <NA>             3.0          NaN
# 3203    TXN_4565754  Smoothie     <NA>             4.0          NaN
# 3224    TXN_6297232    Coffee     <NA>             2.0          NaN
# 3401    TXN_3251829       Tea     <NA>             1.5          NaN
# 3635    TXN_6177081    Cookie     <NA>             1.0          1.0
# 4257    TXN_6470865    Coffee     <NA>             2.0          NaN
# 5639    TXN_6206792       Tea     <NA>             1.5          6.0
# 5841    TXN_5884081    Cookie     <NA>             1.0          NaN
# 5845    TXN_8388462  Smoothie     <NA>             4.0          8.0
# 6225    TXN_6859249    Cookie     <NA>             1.0          2.0
# 6661    TXN_5308047    Cookie     <NA>             1.0          1.0
# 6674    TXN_3071092    Coffee     <NA>             2.0          4.0
# 7029    TXN_4628338    Coffee     <NA>             2.0          NaN
# 7297    TXN_9944500  Smoothie     <NA>             4.0          NaN
# 8021    TXN_2428781     Salad     <NA>             5.0          NaN
# 8443    TXN_2023651  Sandwich     <NA>             4.0          NaN
# 8465    TXN_9669616    Coffee     <NA>             2.0          NaN
# 8479    TXN_1547245  Sandwich     <NA>             4.0          NaN
# 8574    TXN_2546684     Juice     <NA>             3.0          NaN
# 8669    TXN_7764304      Cake     <NA>             3.0          3.0
# 8732    TXN_4550558    Cookie     <NA>             1.0          NaN
# 8975    TXN_8077367       Tea     <NA>             1.5          7.5
# 9464    TXN_5744797      Cake     <NA>             3.0          3.0
# 9590    TXN_9924732  Sandwich     <NA>             4.0          NaN
# 9869    TXN_1975184    Coffee     <NA>             2.0          NaN
#
#       Payment Method  Location Transaction Date
# 236             <NA>  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 629   Digital Wallet  In-store       2023-12-30
# 641             <NA>      <NA>       2023-03-17
# 738             <NA>  Takeaway       2023-05-14
# 912            ERROR  Takeaway       2023-01-05
# 1008     Credit Card  Takeaway       2023-03-07
# 1436            Cash  Takeaway              NaT
# 1482            Cash      <NA>       2023-03-05
# 2330            <NA>  In-store       2023-03-01
# 2796     Credit Card      <NA>       2023-12-01
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224            <NA>      <NA>       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 3635            Cash     ERROR       2023-07-26
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5639     Credit Card      <NA>       2023-10-13
# 5841  Digital Wallet  In-store       2023-07-05
# 5845         UNKNOWN  Takeaway       2023-08-19
# 6225            <NA>   UNKNOWN              NaT
# 6661     Credit Card      <NA>       2023-10-28
# 6674           ERROR      <NA>       2023-09-08
# 7029            Cash      <NA>       2023-12-25
# 7297            Cash  In-store       2023-01-03
# 8021            <NA>  In-store       2023-05-09
# 8443            Cash  In-store       2023-05-25
# 8465            <NA>     ERROR       2023-06-03
# 8479            <NA>  Takeaway       2023-09-11
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8669     Credit Card  Takeaway       2023-01-09
# 8732     Credit Card  In-store       2023-08-04
# 8975     Credit Card      <NA>       2023-02-27
# 9464            Cash  In-store       2023-12-20
# 9590     Credit Card  In-store       2023-01-18
# 9869  Digital Wallet      <NA>       2023-01-15

# %% [markdown]
# Por la tabla que nos devuelve nos muestra que para las 476 filas donde Quantity es un valor NA sabemos el precio y el total, por lo que podemos deducir el valor de Quantity ya que "Quantity * Price Per Unit = Total Spent"

# %% [markdown]
# Tomando en base que esa igualdad de Quantity * Price Per Unit = Total Spent, vamos a crear una función que en el caso de que falte 1 de los 3 valores lo calcule, que si faltan 2 no lo calcule y si alguno no encajase no lo modifique.

# %%
import numpy as np

# %%
def fix_row(row):
    q = row["Quantity"]
    p = row["Price Per Unit"]
    t = row["Total Spent"]
    
    # 1. Si solo falta Total Spent → Quantity * Price
    if pd.isna(t) and pd.notna(q) and pd.notna(p):
        row["Total Spent"] = q * p
    
    # 2. Si solo falta Quantity → Total / Price
    elif pd.isna(q) and pd.notna(t) and pd.notna(p) and p != 0:
        row["Quantity"] = t / p
    
    # 3. Si solo falta Price → Total / Quantity
    elif pd.isna(p) and pd.notna(t) and pd.notna(q) and q != 0:
        row["Price Per Unit"] = t / q
    
    return row

df_cafe_dirty = df_cafe_dirty.apply(fix_row, axis=1)

# %%
df_cafe_dirty.head(15)
# Out:
#    Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee        2             2.0          4.0
# 1     TXN_4977031      Cake        4             3.0         12.0
# 2     TXN_4271903    Cookie        4             1.0          4.0
# 3     TXN_7034554     Salad        2             5.0         10.0
# 4     TXN_3160411    Coffee        2             2.0          4.0
# 5     TXN_2602893  Smoothie        5             4.0         20.0
# 6     TXN_4433211   UNKNOWN        3             3.0          9.0
# 7     TXN_6699534  Sandwich        4             4.0         16.0
# 8     TXN_4717867      <NA>        5             3.0         15.0
# 9     TXN_2064365  Sandwich        5             4.0         20.0
# 10    TXN_2548360     Salad        5             5.0         25.0
# 11    TXN_3051279  Sandwich        2             4.0          8.0
# 12    TXN_7619095  Sandwich        2             4.0          8.0
# 13    TXN_9437049    Cookie        5             1.0          5.0
# 14    TXN_8915701       Tea        2             1.5          3.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card      <NA>       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 8             <NA>  Takeaway       2023-07-28
# 9             <NA>  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway              NaT
# 12            Cash  In-store       2023-05-03
# 13            <NA>  Takeaway       2023-06-01
# 14            <NA>  In-store       2023-03-21

# %%
df_cafe_dirty['Quantity'].isna().sum()
# Out:
# np.int64(20)

# %%
df_cafe_dirty_quantity_na = df_cafe_dirty[df_cafe_dirty["Quantity"].isna()]
df_cafe_dirty_quantity_na
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 236     TXN_8562645     Salad     <NA>             5.0          NaN
# 278     TXN_3229409     Juice     <NA>             3.0          NaN
# 641     TXN_2962976     Juice     <NA>             3.0          NaN
# 738     TXN_8696094  Sandwich     <NA>             4.0          NaN
# 2796    TXN_9188692      Cake     <NA>             3.0          NaN
# 3203    TXN_4565754  Smoothie     <NA>             4.0          NaN
# 3224    TXN_6297232    Coffee     <NA>             2.0          NaN
# 3401    TXN_3251829       Tea     <NA>             1.5          NaN
# 4257    TXN_6470865    Coffee     <NA>             2.0          NaN
# 5841    TXN_5884081    Cookie     <NA>             1.0          NaN
# 7029    TXN_4628338    Coffee     <NA>             2.0          NaN
# 7297    TXN_9944500  Smoothie     <NA>             4.0          NaN
# 8021    TXN_2428781     Salad     <NA>             5.0          NaN
# 8443    TXN_2023651  Sandwich     <NA>             4.0          NaN
# 8465    TXN_9669616    Coffee     <NA>             2.0          NaN
# 8479    TXN_1547245  Sandwich     <NA>             4.0          NaN
# 8574    TXN_2546684     Juice     <NA>             3.0          NaN
# 8732    TXN_4550558    Cookie     <NA>             1.0          NaN
# 9590    TXN_9924732  Sandwich     <NA>             4.0          NaN
# 9869    TXN_1975184    Coffee     <NA>             2.0          NaN
#
#       Payment Method  Location Transaction Date
# 236             <NA>  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 641             <NA>      <NA>       2023-03-17
# 738             <NA>  Takeaway       2023-05-14
# 2796     Credit Card      <NA>       2023-12-01
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224            <NA>      <NA>       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5841  Digital Wallet  In-store       2023-07-05
# 7029            Cash      <NA>       2023-12-25
# 7297            Cash  In-store       2023-01-03
# 8021            <NA>  In-store       2023-05-09
# 8443            Cash  In-store       2023-05-25
# 8465            <NA>     ERROR       2023-06-03
# 8479            <NA>  Takeaway       2023-09-11
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8732     Credit Card  In-store       2023-08-04
# 9590     Credit Card  In-store       2023-01-18
# 9869  Digital Wallet      <NA>       2023-01-15

# %% [markdown]
# Eliminaremos las 20 filas que contienen valores nulos en Quantity y en Total, ya que no nos aportan valor

# %%
df_cafe_dirty = df_cafe_dirty.dropna(subset=["Quantity"])
df_cafe_dirty[["Quantity"]].isna().sum()
# Out:
# Quantity    0
# dtype: int64

# %%
df_cafe_dirty.shape
# Out:
# (9926, 8)

# %%
df_cafe_dirty['Price Per Unit'].isna().sum()
# Out:
# np.int64(0)

# %%
df_cafe_dirty['Total Spent'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Finalmente, las columnas de Quantity, Price Per Unit y Total Spent están libres de nulos

# %%
#¿Item sigue teniendo algún valor nulo?
df_cafe_dirty['Item'].isna().sum()
# Out:
# np.int64(310)

# %%
#Como Item sigue teniendo valores nulos cuyo precio unitario puede coincidir con 2 items diferentes la mejor opción
#será eliminar esas filas, ya que, no son demasiadas.
df_cafe_dirty_item_nan = df_cafe_dirty[df_cafe_dirty['Item'].isna()]
df_cafe_dirty_item_nan
# Out:
#      Transaction ID  Item Quantity  Price Per Unit  Total Spent  \
# 8       TXN_4717867  <NA>        5             3.0         15.0
# 30      TXN_1736287  <NA>        5             2.0         10.0
# 61      TXN_8051289  <NA>        1             3.0          3.0
# 72      TXN_6044979  <NA>        1             1.0          1.0
# 89      TXN_4132730  <NA>        5             1.0          5.0
# ...             ...   ...      ...             ...          ...
# 9771    TXN_9582818  <NA>        1             4.0          4.0
# 9788    TXN_4600894  <NA>        5             5.0         25.0
# 9855    TXN_3740505  <NA>        2             1.5          3.0
# 9876    TXN_3105633  <NA>        1             2.0          2.0
# 9885    TXN_4659954  <NA>        3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 8               <NA>  Takeaway       2023-07-28
# 30    Digital Wallet      <NA>       2023-06-02
# 61              <NA>  In-store       2023-10-09
# 72              Cash  In-store       2023-12-08
# 89              <NA>  In-store       2023-03-12
# ...              ...       ...              ...
# 9771            Cash  In-store       2023-10-27
# 9788  Digital Wallet      <NA>       2023-09-17
# 9855            <NA>      <NA>       2023-11-21
# 9876            <NA>  In-store       2023-03-30
# 9885     Credit Card  In-store              NaT
#
# [310 rows x 8 columns]

# %%
df_cafe_dirty = df_cafe_dirty.dropna(subset=["Item"])
df_cafe_dirty['Item'].isna().sum()
# Out:
# np.int64(0)

# %%
df_cafe_dirty.shape
# Out:
# (9616, 8)

# %%
df_cafe_dirty.head(15)
# Out:
#    Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee        2             2.0          4.0
# 1     TXN_4977031      Cake        4             3.0         12.0
# 2     TXN_4271903    Cookie        4             1.0          4.0
# 3     TXN_7034554     Salad        2             5.0         10.0
# 4     TXN_3160411    Coffee        2             2.0          4.0
# 5     TXN_2602893  Smoothie        5             4.0         20.0
# 6     TXN_4433211   UNKNOWN        3             3.0          9.0
# 7     TXN_6699534  Sandwich        4             4.0         16.0
# 9     TXN_2064365  Sandwich        5             4.0         20.0
# 10    TXN_2548360     Salad        5             5.0         25.0
# 11    TXN_3051279  Sandwich        2             4.0          8.0
# 12    TXN_7619095  Sandwich        2             4.0          8.0
# 13    TXN_9437049    Cookie        5             1.0          5.0
# 14    TXN_8915701       Tea        2             1.5          3.0
# 15    TXN_2847255     Salad        3             5.0         15.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card      <NA>       2023-03-31
# 6            ERROR  Takeaway       2023-10-06
# 7             Cash   UNKNOWN       2023-10-28
# 9             <NA>  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway              NaT
# 12            Cash  In-store       2023-05-03
# 13            <NA>  Takeaway       2023-06-01
# 14            <NA>  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15

# %%
df_cafe_dirty_item_invalid_values = df_cafe_dirty[df_cafe_dirty['Item'].isin(invalid_values)]
df_cafe_dirty_item_invalid_values
# Out:
#      Transaction ID     Item Quantity  Price Per Unit  Total Spent  \
# 6       TXN_4433211  UNKNOWN        3             3.0          9.0
# 36      TXN_6855453  UNKNOWN        4             3.0         12.0
# 69      TXN_8471743    ERROR        5             3.0         15.0
# 91      TXN_5455936  UNKNOWN        5             3.0         15.0
# 153     TXN_6541415  UNKNOWN      4.0             3.0         12.0
# ...             ...      ...      ...             ...          ...
# 9910    TXN_2338617    ERROR        2             3.0          6.0
# 9918    TXN_2292088    ERROR        1             4.0          4.0
# 9946    TXN_8807600  UNKNOWN        1             4.0          4.0
# 9981    TXN_4583012    ERROR        5             4.0         20.0
# 9994    TXN_7851634  UNKNOWN        4             4.0         16.0
#
#       Payment Method  Location Transaction Date
# 6              ERROR  Takeaway       2023-10-06
# 36              <NA>  In-store       2023-07-17
# 69    Digital Wallet  In-store       2023-04-06
# 91              <NA>  In-store       2023-10-28
# 153             Cash  In-store       2023-11-25
# ...              ...       ...              ...
# 9910  Digital Wallet   UNKNOWN       2023-01-12
# 9918  Digital Wallet  Takeaway       2023-03-04
# 9946            Cash  Takeaway       2023-09-24
# 9981  Digital Wallet      <NA>       2023-02-27
# 9994            <NA>      <NA>       2023-01-08
#
# [285 rows x 8 columns]

# %%
#Eliminamos las filas con Unknown y Error (invalid_values previamente definido) ya que, el price per unit nos indica
# que podría ser más de un Item.
df_cafe_dirty = df_cafe_dirty[~df_cafe_dirty['Item'].isin(invalid_values)]
df_cafe_dirty['Item'].isin(invalid_values).sum()
# Out:
# np.int64(0)

# %%
df_cafe_dirty.head(15)
# Out:
#    Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee        2             2.0          4.0
# 1     TXN_4977031      Cake        4             3.0         12.0
# 2     TXN_4271903    Cookie        4             1.0          4.0
# 3     TXN_7034554     Salad        2             5.0         10.0
# 4     TXN_3160411    Coffee        2             2.0          4.0
# 5     TXN_2602893  Smoothie        5             4.0         20.0
# 7     TXN_6699534  Sandwich        4             4.0         16.0
# 9     TXN_2064365  Sandwich        5             4.0         20.0
# 10    TXN_2548360     Salad        5             5.0         25.0
# 11    TXN_3051279  Sandwich        2             4.0          8.0
# 12    TXN_7619095  Sandwich        2             4.0          8.0
# 13    TXN_9437049    Cookie        5             1.0          5.0
# 14    TXN_8915701       Tea        2             1.5          3.0
# 15    TXN_2847255     Salad        3             5.0         15.0
# 16    TXN_3765707  Sandwich        1             4.0          4.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3          UNKNOWN   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card      <NA>       2023-03-31
# 7             Cash   UNKNOWN       2023-10-28
# 9             <NA>  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway              NaT
# 12            Cash  In-store       2023-05-03
# 13            <NA>  Takeaway       2023-06-01
# 14            <NA>  In-store       2023-03-21
# 15     Credit Card  In-store       2023-11-15
# 16            <NA>      <NA>       2023-06-10

# %%
df_cafe_dirty_Payment_method_invalid = df_cafe_dirty[df_cafe_dirty['Payment Method'].isin(invalid_values)]
df_cafe_dirty_Payment_method_invalid
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 3       TXN_7034554     Salad        2             5.0         10.0
# 25      TXN_7958992  Smoothie        3             4.0         12.0
# 39      TXN_6688524    Coffee        4             2.0          8.0
# 51      TXN_6342161     Salad        5             5.0         25.0
# 95      TXN_8268061     Salad        3             5.0         15.0
# ...             ...       ...      ...             ...          ...
# 9955    TXN_9187008       Tea        4             1.5          6.0
# 9972    TXN_3124078      Cake        4             3.0         12.0
# 9980    TXN_6796890       Tea        4             1.5          6.0
# 9988    TXN_9594133      Cake        5             3.0         15.0
# 9992    TXN_2739140  Smoothie        4             4.0         16.0
#
#      Payment Method  Location Transaction Date
# 3           UNKNOWN   UNKNOWN       2023-04-27
# 25          UNKNOWN   UNKNOWN       2023-12-13
# 39            ERROR      <NA>       2023-06-29
# 51            ERROR  Takeaway       2023-01-08
# 95            ERROR  Takeaway       2023-08-20
# ...             ...       ...              ...
# 9955          ERROR      <NA>       2023-09-16
# 9972        UNKNOWN  In-store       2023-08-06
# 9980        UNKNOWN      <NA>       2023-08-24
# 9988          ERROR      <NA>              NaT
# 9992        UNKNOWN  In-store       2023-07-05
#
# [563 rows x 8 columns]

# %%
df_cafe_dirty_Payment_method_nan = df_cafe_dirty[df_cafe_dirty['Payment Method'].isna()]
df_cafe_dirty_Payment_method_nan
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 9       TXN_2064365  Sandwich        5             4.0         20.0
# 13      TXN_9437049    Cookie        5             1.0          5.0
# 14      TXN_8915701       Tea        2             1.5          3.0
# 16      TXN_3765707  Sandwich        1             4.0          4.0
# 23      TXN_2616390  Sandwich        2             4.0          8.0
# ...             ...       ...      ...             ...          ...
# 9976    TXN_3528020    Cookie        1             1.0          1.0
# 9978    TXN_4302199       Tea        3             1.5          4.5
# 9982    TXN_8567525    Cookie        2             1.0          2.0
# 9985    TXN_3297457      Cake        2             3.0          6.0
# 9995    TXN_7672686    Coffee        2             2.0          4.0
#
#      Payment Method  Location Transaction Date
# 9              <NA>  In-store       2023-12-31
# 13             <NA>  Takeaway       2023-06-01
# 14             <NA>  In-store       2023-03-21
# 16             <NA>      <NA>       2023-06-10
# 23             <NA>      <NA>       2023-09-18
# ...             ...       ...              ...
# 9976           <NA>  Takeaway       2023-08-26
# 9978           <NA>      <NA>       2023-02-16
# 9982           <NA>  Takeaway       2023-12-30
# 9985           <NA>   UNKNOWN       2023-01-03
# 9995           <NA>   UNKNOWN       2023-08-30
#
# [2405 rows x 8 columns]

# %%
#Como son muchas filas con valores nulos o invalidos, vamos a transformarlos por un valor que sea "Other"

# %%
def clean_payment_method (value):
    if pd.isna(value) or value in invalid_values:
        return "Other"
    return value

# %%
df_cafe_dirty['Payment Method'] = df_cafe_dirty['Payment Method'].apply(clean_payment_method)

# %%
df_cafe_dirty.head(10)
# Out:
#    Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee        2             2.0          4.0
# 1     TXN_4977031      Cake        4             3.0         12.0
# 2     TXN_4271903    Cookie        4             1.0          4.0
# 3     TXN_7034554     Salad        2             5.0         10.0
# 4     TXN_3160411    Coffee        2             2.0          4.0
# 5     TXN_2602893  Smoothie        5             4.0         20.0
# 7     TXN_6699534  Sandwich        4             4.0         16.0
# 9     TXN_2064365  Sandwich        5             4.0         20.0
# 10    TXN_2548360     Salad        5             5.0         25.0
# 11    TXN_3051279  Sandwich        2             4.0          8.0
#
#     Payment Method  Location Transaction Date
# 0      Credit Card  Takeaway       2023-09-08
# 1             Cash  In-store       2023-05-16
# 2      Credit Card  In-store       2023-07-19
# 3            Other   UNKNOWN       2023-04-27
# 4   Digital Wallet  In-store       2023-06-11
# 5      Credit Card      <NA>       2023-03-31
# 7             Cash   UNKNOWN       2023-10-28
# 9            Other  In-store       2023-12-31
# 10            Cash  Takeaway       2023-11-07
# 11     Credit Card  Takeaway              NaT

# %%
df_cafe_dirty.Location.unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', <NA>, 'ERROR'], dtype=object)

# %%
df_cafe_dirty_location_invalid_values = df_cafe_dirty[df_cafe_dirty['Location'].isin(invalid_values)]
df_cafe_dirty_location_invalid_values
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 3       TXN_7034554     Salad        2             5.0         10.0
# 7       TXN_6699534  Sandwich        4             4.0         16.0
# 18      TXN_8876618      Cake        5             3.0         15.0
# 25      TXN_7958992  Smoothie        3             4.0         12.0
# 31      TXN_8927252    Cookie        2             1.0          2.0
# ...             ...       ...      ...             ...          ...
# 9913    TXN_8408353       Tea        1             1.5          1.5
# 9931    TXN_8344810  Smoothie        2             4.0          8.0
# 9939    TXN_9026468  Sandwich        2             4.0          8.0
# 9985    TXN_3297457      Cake        2             3.0          6.0
# 9995    TXN_7672686    Coffee        2             2.0          4.0
#
#      Payment Method Location Transaction Date
# 3             Other  UNKNOWN       2023-04-27
# 7              Cash  UNKNOWN       2023-10-28
# 18             Cash    ERROR       2023-03-25
# 25            Other  UNKNOWN       2023-12-13
# 31      Credit Card    ERROR       2023-11-06
# ...             ...      ...              ...
# 9913    Credit Card  UNKNOWN       2023-12-13
# 9931          Other  UNKNOWN              NaT
# 9939    Credit Card    ERROR       2023-08-23
# 9985          Other  UNKNOWN       2023-01-03
# 9995          Other  UNKNOWN       2023-08-30
#
# [661 rows x 8 columns]

# %%
df_cafe_dirty_location_nan = df_cafe_dirty[df_cafe_dirty['Location'].isna()]
df_cafe_dirty_location_nan
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 5       TXN_2602893  Smoothie        5             4.0         20.0
# 16      TXN_3765707  Sandwich        1             4.0          4.0
# 23      TXN_2616390  Sandwich        2             4.0          8.0
# 28      TXN_8467949  Smoothie        5             4.0         20.0
# 33      TXN_7710508    Cookie        5             1.0          5.0
# ...             ...       ...      ...             ...          ...
# 9989    TXN_1741685     Juice        5             3.0         15.0
# 9990    TXN_1538510    Coffee        5             2.0         10.0
# 9993    TXN_4766549  Smoothie        2             4.0          8.0
# 9997    TXN_5255387    Coffee        4             2.0          8.0
# 9998    TXN_7695629    Cookie        3             1.0          3.0
#
#       Payment Method Location Transaction Date
# 5        Credit Card     <NA>       2023-03-31
# 16             Other     <NA>       2023-06-10
# 23             Other     <NA>       2023-09-18
# 28       Credit Card     <NA>       2023-03-11
# 33              Cash     <NA>              NaT
# ...              ...      ...              ...
# 9989            Cash     <NA>       2023-08-18
# 9990  Digital Wallet     <NA>       2023-05-22
# 9993            Cash     <NA>       2023-10-20
# 9997  Digital Wallet     <NA>       2023-03-02
# 9998  Digital Wallet     <NA>       2023-12-02
#
# [3040 rows x 8 columns]

# %%
#Demasiados valores nulos o invalid_values.
# Toma de decisión: ¿Cambiamos los valores nulos o invalid_values o eliminamos la columna al faltar 1/3 de los valores?
# Voy a escoger la opción de cambiar los valores nulos e invalidos y unificarlos a Location Not Saved

# %%
df_cafe_dirty['Transaction Date'] = df_cafe_dirty['Transaction Date'].dt.strftime('%d/%m/%Y')
#invertir el orden de la fecha para que aparezca primero el día después el mes y por último el año

# %%
df_cafe_dirty.head(6)
# Out:
#   Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373    Coffee        2             2.0          4.0
# 1    TXN_4977031      Cake        4             3.0         12.0
# 2    TXN_4271903    Cookie        4             1.0          4.0
# 3    TXN_7034554     Salad        2             5.0         10.0
# 4    TXN_3160411    Coffee        2             2.0          4.0
# 5    TXN_2602893  Smoothie        5             4.0         20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       08/09/2023
# 1            Cash  In-store       16/05/2023
# 2     Credit Card  In-store       19/07/2023
# 3           Other   UNKNOWN       27/04/2023
# 4  Digital Wallet  In-store       11/06/2023
# 5     Credit Card      <NA>       31/03/2023

# %%
#Defino la función para modificar valores en Location:
def clean_location (value):
    if pd.isna(value) or value in invalid_values:
        return "Not Saved"
    return value

# %%
df_cafe_dirty['Location'] = df_cafe_dirty['Location'].apply(clean_location)

# %%
df_cafe_dirty.sample(10)
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 9504    TXN_8532735    Coffee        2             2.0          4.0
# 8565    TXN_9061106      Cake        4             3.0         12.0
# 3120    TXN_2052609      Cake        4             3.0         12.0
# 8735    TXN_6744096    Coffee        1             2.0          2.0
# 4698    TXN_2273573    Cookie        5             1.0          5.0
# 6225    TXN_6859249    Cookie      2.0             1.0          2.0
# 488     TXN_4769307       Tea        5             1.5          7.5
# 917     TXN_2826603     Salad        2             5.0         10.0
# 2614    TXN_4269933  Smoothie        2             4.0          8.0
# 3081    TXN_3421456      Cake      1.0             3.0          3.0
#
#       Payment Method   Location Transaction Date
# 9504            Cash   Takeaway       28/07/2023
# 8565  Digital Wallet   Takeaway       04/11/2023
# 3120     Credit Card   Takeaway       23/06/2023
# 8735  Digital Wallet   In-store       15/11/2023
# 4698            Cash   In-store       12/11/2023
# 6225           Other  Not Saved              NaN
# 488   Digital Wallet  Not Saved       24/12/2023
# 917   Digital Wallet   Takeaway       22/06/2023
# 2614           Other   Takeaway       28/03/2023
# 3081           Other  Not Saved       05/09/2023

# %%
df_cafe_dirty_transaction_date_nat = df_cafe_dirty[df_cafe_dirty['Transaction Date'].isna()]
df_cafe_dirty_transaction_date_nat
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 11      TXN_3051279  Sandwich        2             4.0          8.0
# 29      TXN_7640952      Cake        4             3.0         12.0
# 33      TXN_7710508    Cookie        5             1.0          5.0
# 77      TXN_2091733     Salad        1             5.0          5.0
# 103     TXN_7028009      Cake        4             3.0         12.0
# ...             ...       ...      ...             ...          ...
# 9933    TXN_9460419      Cake        1             3.0          3.0
# 9937    TXN_8253472      Cake        1             3.0          3.0
# 9949    TXN_3130865     Juice        3             3.0          9.0
# 9983    TXN_9226047  Smoothie        3             4.0         12.0
# 9988    TXN_9594133      Cake        5             3.0         15.0
#
#       Payment Method   Location Transaction Date
# 11       Credit Card   Takeaway              NaN
# 29    Digital Wallet   Takeaway              NaN
# 33              Cash  Not Saved              NaN
# 77             Other   In-store              NaN
# 103            Other   Takeaway              NaN
# ...              ...        ...              ...
# 9933           Other   Takeaway              NaN
# 9937           Other  Not Saved              NaN
# 9949           Other   In-store              NaN
# 9983            Cash  Not Saved              NaN
# 9988           Other  Not Saved              NaN
#
# [429 rows x 8 columns]

# %%
def clean_time (value):
    if pd.isna(value) or value in invalid_values:
        return "Not Time"
    return value

# %%
df_cafe_dirty['Transaction Date'] = df_cafe_dirty['Transaction Date'].apply(clean_time)

# %%
df_cafe_dirty.sample(30)
# Out:
#      Transaction ID      Item Quantity  Price Per Unit  Total Spent  \
# 2918    TXN_9365558     Salad        4             5.0         20.0
# 8003    TXN_8992377      Cake        4             3.0         12.0
# 2948    TXN_5234368    Coffee        3             2.0          6.0
# 7833    TXN_8107005     Juice        3             3.0          9.0
# 2096    TXN_7415686  Sandwich        3             4.0         12.0
# 2732    TXN_7092761     Salad        4             5.0         20.0
# 3698    TXN_6083650    Coffee        2             2.0          4.0
# 4156    TXN_9269683  Sandwich        5             4.0         20.0
# 5022    TXN_1495371  Sandwich        2             4.0          8.0
# 5473    TXN_5826333    Cookie        1             1.0          1.0
# 572     TXN_4669664    Cookie        1             1.0          1.0
# 7371    TXN_9845746      Cake        1             3.0          3.0
# 2609    TXN_9708144  Smoothie        3             4.0         12.0
# 405     TXN_5939055    Coffee        3             2.0          6.0
# 3818    TXN_1902038    Coffee        4             2.0          8.0
# 4294    TXN_9723314    Coffee        4             2.0          8.0
# 5926    TXN_6231475     Salad        2             5.0         10.0
# 6955    TXN_2250898  Smoothie      3.0             4.0         12.0
# 6216    TXN_1599516     Juice        3             3.0          9.0
# 3352    TXN_4151440      Cake        5             3.0         15.0
# 817     TXN_4916272       Tea        3             1.5          4.5
# 8177    TXN_5215704  Sandwich        5             4.0         20.0
# 8344    TXN_9772498      Cake        4             3.0         12.0
# 615     TXN_1123138     Salad        1             5.0          5.0
# 8404    TXN_8228500       Tea        3             1.5          4.5
# 63      TXN_9099694     Salad        3             5.0         15.0
# 1595    TXN_2878078      Cake        2             3.0          6.0
# 2750    TXN_1375992    Coffee        5             2.0         10.0
# 3689    TXN_9810868    Cookie        1             1.0          1.0
# 3283    TXN_6252589  Smoothie        2             4.0          8.0
#
#       Payment Method   Location Transaction Date
# 2918     Credit Card   Takeaway       12/02/2023
# 8003     Credit Card   Takeaway       12/07/2023
# 2948  Digital Wallet  Not Saved       10/06/2023
# 7833           Other  Not Saved       15/09/2023
# 2096     Credit Card   In-store       13/04/2023
# 2732           Other  Not Saved       11/05/2023
# 3698  Digital Wallet   Takeaway       01/07/2023
# 4156  Digital Wallet  Not Saved       26/09/2023
# 5022     Credit Card   Takeaway       21/07/2023
# 5473            Cash  Not Saved       14/05/2023
# 572   Digital Wallet   In-store       21/12/2023
# 7371  Digital Wallet   In-store       23/09/2023
# 2609            Cash  Not Saved       18/04/2023
# 405            Other   Takeaway       21/10/2023
# 3818     Credit Card   Takeaway       07/04/2023
# 4294            Cash   In-store       10/10/2023
# 5926     Credit Card   In-store       18/03/2023
# 6955     Credit Card  Not Saved       23/12/2023
# 6216            Cash   In-store       11/05/2023
# 3352           Other   In-store       16/11/2023
# 817            Other  Not Saved       03/03/2023
# 8177     Credit Card  Not Saved       31/10/2023
# 8344            Cash  Not Saved       21/08/2023
# 615             Cash   In-store       10/02/2023
# 8404           Other   In-store       15/04/2023
# 63             Other   Takeaway       18/11/2023
# 1595  Digital Wallet   Takeaway       15/12/2023
# 2750     Credit Card   In-store       23/03/2023
# 3689     Credit Card   Takeaway       05/10/2023
# 3283  Digital Wallet   In-store         Not Time

# %%
df_cafe_dirty.to_csv('dataset cafe limip', index = False)
